# %% [markdown]
# ## Milestone 2: Global Land-Ocean Temperature Index Data Set Analysis
# ### By Mitra Iyer
# ### November 25th, 2025

# %% [markdown]
# #### imports

# %%
import pandas as pd

# %% [markdown]
# #### import dataframe

# %%
file_path = 'global-land-oceantempindex.xlsx'

# %%
df = pd.read_excel(file_path)

# %%
df
# Out:
#      Year   Temperature Anomaly\n(deg C)  \
# 0     1880                         -0.16
# 1     1881                         -0.08
# 2     1882                         -0.11
# 3     1883                         -0.17
# 4     1884                         -0.28
# ..     ...                           ...
# 138   2018                          0.85
# 139   2019                          0.97
# 140   2020                          1.02
# 141   2021                          0.85
# 142   2022                          0.89
#
#      Smoothed Temperature Anomaly\n(deg C) Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                    -0.09
# 1                                    -0.13        NaN        NaN        NaN
# 2                                    -0.16        NaN        NaN        NaN
# 3                                    -0.20        NaN        NaN        NaN
# 4                                    -0.24        NaN        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['Year ', 'Temperature Anomaly\n(deg C)',
#        'Smoothed Temperature Anomaly\n(deg C)', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# ### Clean all NANS from the unnamed columns

# %% [markdown]
# #### create a list that drops all unnamed columns with nans

# %%
cols_to_drop = ['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
                'Unnamed: 8', 'Unnamed: 9']

# %% [markdown]
# #### drop all the unnamed columns

# %%
df = df.drop(columns = cols_to_drop)

# %% [markdown]
# #### check dataframe

# %%
df.columns
# Out:
# Index(['Year ', 'Temperature Anomaly\n(deg C)',
#        'Smoothed Temperature Anomaly\n(deg C)'],
#       dtype='object')

# %%
df
# Out:
#      Year   Temperature Anomaly\n(deg C)  \
# 0     1880                         -0.16
# 1     1881                         -0.08
# 2     1882                         -0.11
# 3     1883                         -0.17
# 4     1884                         -0.28
# ..     ...                           ...
# 138   2018                          0.85
# 139   2019                          0.97
# 140   2020                          1.02
# 141   2021                          0.85
# 142   2022                          0.89
#
#      Smoothed Temperature Anomaly\n(deg C)
# 0                                    -0.09
# 1                                    -0.13
# 2                                    -0.16
# 3                                    -0.20
# 4                                    -0.24
# ..                                     ...
# 138                                   0.93
# 139                                   0.92
# 140                                   0.92
# ...

# %% [markdown]
# ### Now print out the properties of the dataset

# %% [markdown]
# #### describe the data

# %%
df.describe()
# Out:
#             Year   Temperature Anomaly\n(deg C)  \
# count   143.00000                    143.000000
# mean   1951.00000                      0.059930
# std      41.42463                      0.367721
# min    1880.00000                     -0.480000
# 25%    1915.50000                     -0.200000
# 50%    1951.00000                     -0.060000
# 75%    1986.50000                      0.265000
# max    2022.00000                      1.020000
#
#        Smoothed Temperature Anomaly\n(deg C)
# count                             143.000000
# mean                                0.059301
# std                                 0.356101
# min                                -0.410000
# 25%                                -0.220000
# 50%                                -0.040000
# 75%                                 0.255000
# max                                 0.930000

# %% [markdown]
# #### print out all the columns

# %%
df.columns
# Out:
# Index(['Year ', 'Temperature Anomaly\n(deg C)',
#        'Smoothed Temperature Anomaly\n(deg C)'],
#       dtype='object')

# %% [markdown]
# #### describe the shape (rows/columns)

# %%
df.shape
# Out:
# (143, 3)

# %% [markdown]
# #### describe all the datatypes

# %%
df.dtypes
# Out:
# Year                                       int64
# Temperature Anomaly\n(deg C)             float64
# Smoothed Temperature Anomaly\n(deg C)    float64
# dtype: object

# %% [markdown]
# #### print out the first 5 rows of data

# %%
df.head()
# Out:
#    Year   Temperature Anomaly\n(deg C)  Smoothed Temperature Anomaly\n(deg C)
# 0   1880                         -0.16                                  -0.09
# 1   1881                         -0.08                                  -0.13
# 2   1882                         -0.11                                  -0.16
# 3   1883                         -0.17                                  -0.20
# 4   1884                         -0.28                                  -0.24

# %% [markdown]
# #### print out the last 5 rows of data

# %%
df.tail()
# Out:
#      Year   Temperature Anomaly\n(deg C)  \
# 138   2018                          0.85
# 139   2019                          0.97
# 140   2020                          1.02
# 141   2021                          0.85
# 142   2022                          0.89
#
#      Smoothed Temperature Anomaly\n(deg C)
# 138                                   0.93
# 139                                   0.92
# 140                                   0.92
# 141                                   0.91
# 142                                   0.90

# %% [markdown]
# #### print out one row of data

# %%
df.sample()
# Out:
#      Year   Temperature Anomaly\n(deg C)  \
# 105   1985                          0.12
#
#      Smoothed Temperature Anomaly\n(deg C)
# 105                                   0.22

# %% [markdown]
# #### print out info about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 3 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Year                                  143 non-null    int64
#  1   Temperature Anomaly
# (deg C)           143 non-null    float64
#  2   Smoothed Temperature Anomaly
# (deg C)  143 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 3.5 KB
